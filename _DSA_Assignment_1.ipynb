# %% [markdown]
# # 1. Read the dataset to python environment.

# %%
import pandas as pd
import xlrd
df=pd.read_excel("D:/ICTK-Learning/Python Programing Folder/DSA_Assignments/iris.xls")
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 2. Display the columns in the dataset.

# %%
df.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# # 3. Calculate the mean of each column of the dataset.

# %%
print('Mean value of SL:',df['SL'].mean())
print('Mean value of SW:',df['SW'].mean())
print('Mean value of PL:',df['PL'].mean())
print('Mean value of PW:',df['PW'].mean())
# Out:
# Mean value of SL: 5.843333333333335
# Mean value of SW: 3.0540000000000007
# Mean value of PL: 3.7586666666666693
# Mean value of PW: 1.1986666666666672

# %% [markdown]
# # 4. Check for the null values present in the dataset.

# %%
null_value=print(df.isnull().sum())
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset.
# # Bring at least 3 visualizations.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Box plot

# %%
plt.figure(figsize=(12,10))
plt.subplot(2,2,1)
sns.boxplot(x='Classification',y='SL',data=df)
plt.subplot(2,2,2)
sns.boxplot(x='Classification',y='SW',data=df)
plt.subplot(2,2,3)
sns.boxplot(x='Classification',y='PL',data=df)
plt.subplot(2,2,4)
sns.boxplot(x='Classification',y='PW',data=df)
plt.show()

# %% [markdown]
#  # Scatter plot

# %%
plt.figure(figsize=(8,9))
#plt.scatterplot(df['PL'],df['PW'],s=15)
plt.title("PL-PW ")
plt.xlabel('PL')
plt.ylabel('PW')
sns.scatterplot(x='PL', y='PW',hue='Classification', data=df,s=30 )
plt.legend(bbox_to_anchor=(1,1), loc=2)

# %%
plt.figure(figsize=(8,9))

plt.title("SL-SW ")
plt.xlabel('SL')
plt.ylabel('SW')
sns.scatterplot(x='SL', y='SW',hue='Classification', data=df,s=30)
plt.legend(bbox_to_anchor=(1,1), loc=2)

# %%
sns.countplot(x='Classification', data=df, )
plt.show()

# %%
import os
os.getcwd()
# Out:
# 'D:\\ICTK-Learning\\Python Programing Folder\\DSA_Assignments'
